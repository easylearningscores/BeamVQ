# %%
import matplotlib.pyplot as plt

# Ensure Times New Roman is used
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20  # Default font size for all text

# SSIM
convlstm = [0.8619215534230324, 0.7628932063418729, 0.729584956314433, 0.6711153495880234, 0.6157881591168723, 0.6108328140599496, 0.5979186334651322, 0.5700692607364097, 0.5804839576036679, 0.6030466904969074]
convlstm_beamvq = [0.9100923086713815, 0.8720919914639808, 0.8468365397262215, 0.8304965512967678, 0.8142325416332311, 0.8179795308457742, 0.7851457906335727, 0.7466018888273396, 0.7236084274943629, 0.7306406472545359]
fno = [0.8817643726698741, 0.8492995692758692, 0.8104887220769202, 0.7679458264803141, 0.7607503941135, 0.7191708192481585, 0.728158910015309, 0.694076339552324, 0.6838403384052041, 0.6866501435892799]
fno_beamvq = [0.8703738065363719, 0.860071707337337, 0.8471235599142901, 0.8346886669357784, 0.8136489236908416, 0.7923901105062643, 0.7949608694086479, 0.7334930247510887, 0.7362773328938983, 0.7241916200187607]
cno = [0.8916423121880016, 0.8377241861882456, 0.7689028657838385, 0.7711731479040875, 0.7803104596732153, 0.7494147459845703, 0.7154547866306958, 0.6614103990425766, 0.6549705955433213, 0.6521164626874224]
cno_beamvq = [0.8943083874675568, 0.8634849742232676, 0.8661584605477523, 0.8217330229223355, 0.7737480222583083, 0.7406237823148278, 0.7454448796624175, 0.7297209823532744, 0.7221633243324971, 0.7248912749778231]

# Epochs
epochs = range(1, 11)

# Colors
colors = ['#E64B35CC', '#4DBBD5CC', '#3C5488CC', '#00A087CC', '#F39B7FCC', '#8491B4CC']

# Plotting
linewidth = 7
plt.figure(figsize=(6, 6))
plt.plot(epochs, convlstm, '--', color=colors[0], label='ConvLSTM', linewidth=linewidth)
plt.plot(epochs, convlstm_beamvq, '-', color=colors[1], label='ConvLSTM with BeamVQ', linewidth=linewidth)
plt.plot(epochs, fno, '--', color=colors[2], label='FNO', linewidth=linewidth)
plt.plot(epochs, fno_beamvq, '-', color=colors[3], label='FNO with BeamVQ', linewidth=linewidth)
plt.plot(epochs, cno, '--', color=colors[4], label='CNO', linewidth=linewidth)
plt.plot(epochs, cno_beamvq, '-', color=colors[5], label='CNO with BeamVQ', linewidth=linewidth)

# plt.title('Model Performance Over Epochs', fontsize=20)
# plt.xlabel('Epoch', fontsize=20)
# plt.ylabel('Performance', fontsize=20)
plt.legend(fontsize=14)
plt.grid(True)
plt.savefig("ssim.png", dpi=500)
plt.show()

# %%
import matplotlib.pyplot as plt

# Ensure Times New Roman is used
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20  # Default font size for all text

# RMSE
convlstm = [0.24266528, 0.34934932, 0.3941353, 0.43302128, 0.46675992, 0.47660264, 0.47902608, 0.5091658, 0.5251027, 0.52667004] 

convlstm_beamvq = [0.18834943, 0.22086847, 0.23687959, 0.24398504, 0.25813937, 0.27414352, 0.30560315, 0.31229886, 0.34128004, 0.36386958]

fno = [0.20789601, 0.24381717, 0.26616058, 0.298458, 0.31793457, 0.32882613, 0.3378059, 0.3567484, 0.3882153, 0.43331102] 

fno_beamvq = [0.22638376, 0.23202957, 0.23242888, 0.24293776, 0.27892202, 0.28312078, 0.2940279, 0.32229236, 0.3462521, 0.38444576]

cno = [0.1832363, 0.21589693, 0.26838073, 0.29581478, 0.31362668, 0.34255654, 0.3793843, 0.4134436, 0.44043446, 0.44965333]

cno_beamvq = [0.20323114, 0.22967629, 0.24074876, 0.2699664, 0.3018875, 0.31889132, 0.32733396, 0.3400561, 0.37266478, 0.39548442] 


# Epochs
epochs = range(1, 11)

# Colors
colors = ['#E64B35CC', '#4DBBD5CC', '#3C5488CC', '#00A087CC', '#F39B7FCC', '#8491B4CC']

# Plotting
linewidth = 7
plt.figure(figsize=(6, 6))
plt.plot(epochs, convlstm, '--', color=colors[0], label='ConvLSTM', linewidth=linewidth)
plt.plot(epochs, convlstm_beamvq, '-', color=colors[1], label='ConvLSTM with BeamVQ', linewidth=linewidth)
plt.plot(epochs, fno, '--', color=colors[2], label='FNO', linewidth=linewidth)
plt.plot(epochs, fno_beamvq, '-', color=colors[3], label='FNO with BeamVQ', linewidth=linewidth)
plt.plot(epochs, cno, '--', color=colors[4], label='CNO', linewidth=linewidth)
plt.plot(epochs, cno_beamvq, '-', color=colors[5], label='CNO with BeamVQ', linewidth=linewidth)


# plt.title('Model Performance Over Epochs', fontsize=20)
# plt.xlabel('Epoch', fontsize=20)
# plt.ylabel('Performance', fontsize=20)
plt.legend(fontsize=14)
plt.grid(True)
plt.savefig("RMSE.png", dpi=500)
plt.show()

# %%
import matplotlib.pyplot as plt

# Ensure Times New Roman is used
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20  # Default font size for all text

# relative L2 error
convlstm =  [0.13169144, 0.18825376, 0.21060114, 0.22956873, 0.24680978, 0.25301072, 0.25494236, 0.2702257, 0.2762263, 0.273459]

convlstm_beamvq = [0.1022149, 0.119019315, 0.12657358, 0.12935007, 0.13649699, 0.14553265, 0.162645, 0.165744, 0.17952777, 0.18892932]

fno =[0.11282259, 0.13138567, 0.14221948, 0.1582292, 0.16811505, 0.17456165, 0.1797836, 0.18933438, 0.20421772, 0.22498488]

fno_beamvq =  [0.12285567, 0.12503369, 0.12419539, 0.12879485, 0.14748627, 0.15029836, 0.15648451, 0.17104778, 0.1821433, 0.19961293]

cno = [0.09944006, 0.1163403, 0.1434058, 0.15682791, 0.16583717, 0.18185061, 0.20191202, 0.21942379, 0.2316872, 0.23347019]

cno_beamvq = [0.110291034, 0.12376558, 0.12864101, 0.14312424, 0.1596298, 0.16928759, 0.17421035, 0.18047538, 0.19603749, 0.20534447]



# Epochs
epochs = range(1, 11)

# Colors
colors = ['#E64B35CC', '#4DBBD5CC', '#3C5488CC', '#00A087CC', '#F39B7FCC', '#8491B4CC']

# Plotting
linewidth = 7
plt.figure(figsize=(6, 6))
plt.plot(epochs, convlstm, '--', color=colors[0], label='ConvLSTM', linewidth=linewidth)
plt.plot(epochs, convlstm_beamvq, '-', color=colors[1], label='ConvLSTM with BeamVQ', linewidth=linewidth)
plt.plot(epochs, fno, '--', color=colors[2], label='FNO', linewidth=linewidth)
plt.plot(epochs, fno_beamvq, '-', color=colors[3], label='FNO with BeamVQ', linewidth=linewidth)
plt.plot(epochs, cno, '--', color=colors[4], label='CNO', linewidth=linewidth)
plt.plot(epochs, cno_beamvq, '-', color=colors[5], label='CNO with BeamVQ', linewidth=linewidth)


# plt.title('Model Performance Over Epochs', fontsize=20)
# plt.xlabel('Epoch', fontsize=20)
# plt.ylabel('Performance', fontsize=20)
plt.legend(fontsize=14)
plt.grid(True)
plt.savefig("rl2m.png", dpi=500)
plt.show()
